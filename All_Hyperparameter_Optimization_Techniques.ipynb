# %% [markdown]
# ### All Techniques Of Hyper Parameter Optimization
#
# - **GridSearchCV**
# - **RandomizedSearchCV**
# - **Bayesian Optimization** - Automate Hyperparameter Tuning (Hyperopt)
# - **Sequential Model Based Optimization**(Tuning a scikit-learn estimator with skopt)
# - **Optuna** - Automate Hyperparameter Tuning
# - **Genetic Algorithms** (TPOT Classifier)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
df = pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df["Glucose"] = np.where(df["Glucose"]==0,df["Glucose"].median(),df["Glucose"])
df["Insulin"] = np.where(df["Insulin"]==0,df["Insulin"].median(),df["Insulin"])
df["SkinThickness"] = np.where(df["SkinThickness"]==0,df["SkinThickness"].median(),df["SkinThickness"])

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.656250      69.105469      27.334635   94.652344
# std       3.369578   30.438286      19.355807       9.229014  105.547598
# min       0.000000   44.000000       0.000000       7.000000   14.000000
# 25%       1.000000   99.750000      62.000000      23.000000   30.500000
# 50%       3.000000  117.000000      72.000000      23.000000   31.250000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0             72           35.0     30.5  33.6
# 1            1     85.0             66           29.0     30.5  26.6
# 2            8    183.0             64           23.0     30.5  23.3
# 3            1     89.0             66           23.0     94.0  28.1
# 4            0    137.0             40           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Independent and dependent features
X = df.drop("Outcome",axis=1)
y = df["Outcome"]

# %%
y.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
# train,test and split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
rf = RandomForestClassifier(n_estimators=10)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)

# %%
print("Accuracy_score:\n",accuracy_score(y_test,y_pred))
print("confusion matrix:\n",confusion_matrix(y_test,y_pred))
print("classification report:\n",classification_report(y_test,y_pred))
# Out:
# Accuracy_score:
#  0.8116883116883117
# confusion matrix:
#  [[99  8]
#  [21 26]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       107
#            1       0.76      0.55      0.64        47
#
#     accuracy                           0.81       154
#    macro avg       0.79      0.74      0.76       154
# weighted avg       0.81      0.81      0.80       154

# %% [markdown]
# The main parameters used by a Random Forest Classifier are:
#
# - **criterion** = the function used to evaluate the quality of a split.
# - **max_depth** = maximum number of levels allowed in each tree.
# - **max_features** = maximum number of features considered when splitting a node.
# - **min_samples_leaf** = minimum number of samples which can be stored in a tree leaf.
# - **min_samples_split** = minimum number of samples necessary in a node to cause node splitting.
# - **n_estimators** = number of trees in the ensamble.

# %%
### Manual HyperParameter Tuning
model = RandomForestClassifier(n_estimators=300,criterion="entropy",
                              max_features="sqrt",min_samples_leaf=10,random_state=100)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
print("Accuracy_score:\n",accuracy_score(y_test,y_pred))
print("confusion matrix:\n",confusion_matrix(y_test,y_pred))
print("classification report:\n",classification_report(y_test,y_pred))
# Out:
# Accuracy_score:
#  0.8246753246753247
# confusion matrix:
#  [[97 10]
#  [17 30]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88       107
#            1       0.75      0.64      0.69        47
#
#     accuracy                           0.82       154
#    macro avg       0.80      0.77      0.78       154
# weighted avg       0.82      0.82      0.82       154

# %%
### Manual HyperParameter Tuning
model = RandomForestClassifier(n_estimators=500,criterion="gini",
                              max_features="sqrt",min_samples_leaf=10,random_state=100)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
print("Accuracy_score:\n",accuracy_score(y_test,y_pred))
print("confusion matrix:\n",confusion_matrix(y_test,y_pred))
print("classification report:\n",classification_report(y_test,y_pred))
# Out:
# Accuracy_score:
#  0.8116883116883117
# confusion matrix:
#  [[97 10]
#  [19 28]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87       107
#            1       0.74      0.60      0.66        47
#
#     accuracy                           0.81       154
#    macro avg       0.79      0.75      0.76       154
# weighted avg       0.81      0.81      0.81       154

# %% [markdown]
# We need to use randomized Search CV first and then use Grid Search CV

# %% [markdown]
# ### Randomized Search CV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {
 # Number of trees in random forest
"n_estimators": [int(x) for x in np.linspace(200,2000,10)],
 # Number of features to consider at every split
"max_features" : ["auto","sqrt","log2"],
 # Maximum number of levels in tree
"max_depth" : [int(x) for x in np.linspace(10,1000,10)],
 # Minimum number of samples required to split a node
"min_samples_split": [1,3,4,5,7,9],
 # Minimum number of samples required at each leaf node
"min_samples_leaf" : [1,2,4,6,8],
"criterion":["entropy","gini"]
    }

# %%
print(params)
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [1, 3, 4, 5, 7, 9], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}

# %%
rf = RandomForestClassifier()
rand = RandomizedSearchCV(rf,params,n_iter=100,cv=3,random_state=100,verbose=2)
rand.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=1600; total time=   4.2s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=1600; total time=   3.7s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=1600; total time=   3.7s
# [CV] END criterion=gini, max_depth=340, max_features=sqrt, min_samples_leaf=2, min_samples_split=9, n_estimators=2000; total time=   4.4s
# [CV] END criterion=gini, max_depth=340, max_features=sqrt, min_samples_leaf=2, min_samples_split=9, n_estimators=2000; total time=   4.4s
# [CV] END criterion=gini, max_depth=340, max_features=sqrt, min_samples_leaf=2, min_samples_split=9, n_estimators=2000; total time=   5.6s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=2000; total time=   6.2s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=2000; total time=   5.6s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=2000; total time=   5.2s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=1000; total time=   2.0s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=1000; total time=   2.2s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=1000; total time=   1.8s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=1000; total time=   2.1s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=1000; total time=   1.9s
# [CV] END criterion=gini, max_depth=890, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=1000; total time=   2.0s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=120, max_features=auto, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.2s
# [CV] END criterion=gini, max_depth=120, max_features=auto, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.2s
# [CV] END criterion=gini, max_depth=120, max_features=auto, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.2s
# [CV] END criterion=gini, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=1400; total time=   3.2s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=1400; total time=   3.2s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=1400; total time=   3.6s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=1400; total time=   0.5s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=1400; total time=   0.6s
# [CV] END criterion=entropy, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=1400; total time=   0.6s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1400; total time=   2.8s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1400; total time=   2.6s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1400; total time=   3.0s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=   3.6s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=   5.6s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1600; total time=   4.9s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=6, min_samples_split=3, n_estimators=600; total time=   1.5s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=6, min_samples_split=3, n_estimators=600; total time=   1.4s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=6, min_samples_split=3, n_estimators=600; total time=   1.8s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   1.9s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   1.6s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   1.7s
# [CV] END criterion=gini, max_depth=1000, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=1000; total time=   2.7s
# [CV] END criterion=gini, max_depth=1000, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=1000; total time=   2.8s
# [CV] END criterion=gini, max_depth=1000, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=1000; total time=   3.0s
# [CV] END criterion=entropy, max_depth=890, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=1800; total time=   5.2s
# [CV] END criterion=entropy, max_depth=890, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=1800; total time=   4.7s
# [CV] END criterion=entropy, max_depth=890, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=1800; total time=   4.4s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600; total time=   1.8s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600; total time=   1.6s
# [CV] END criterion=gini, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=600; total time=   1.7s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=1, n_estimators=800; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=1, n_estimators=800; total time=   0.3s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=1, n_estimators=800; total time=   0.7s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=2, min_samples_split=1, n_estimators=2000; total time=   1.0s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=2, min_samples_split=1, n_estimators=2000; total time=   1.3s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=2, min_samples_split=1, n_estimators=2000; total time=   1.2s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=   1.8s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=   1.9s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=800; total time=   1.8s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=200; total time=   0.7s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=1600; total time=   4.9s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=1600; total time=   4.6s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=1600; total time=   4.0s
# [CV] END criterion=entropy, max_depth=340, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   1.9s
# [CV] END criterion=entropy, max_depth=340, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   1.5s
# [CV] END criterion=entropy, max_depth=340, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   1.6s
# [CV] END criterion=entropy, max_depth=780, max_features=log2, min_samples_leaf=1, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=entropy, max_depth=780, max_features=log2, min_samples_leaf=1, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=entropy, max_depth=780, max_features=log2, min_samples_leaf=1, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=450, max_features=sqrt, min_samples_leaf=1, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=sqrt, min_samples_leaf=1, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=450, max_features=sqrt, min_samples_leaf=1, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=800; total time=   1.5s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=800; total time=   1.8s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=800; total time=   1.7s
# [CV] END criterion=gini, max_depth=340, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=2000; total time=   4.9s
# [CV] END criterion=gini, max_depth=340, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=2000; total time=   5.2s
# [CV] END criterion=gini, max_depth=340, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=2000; total time=   5.9s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=8, min_samples_split=9, n_estimators=1200; total time=   3.8s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=8, min_samples_split=9, n_estimators=1200; total time=   3.8s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=8, min_samples_split=9, n_estimators=1200; total time=   2.9s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=1600; total time=   6.9s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=1600; total time=   6.6s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=1600; total time=   6.8s
# [CV] END criterion=gini, max_depth=450, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=200; total time=   0.7s
# [CV] END criterion=gini, max_depth=450, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=200; total time=   1.1s
# [CV] END criterion=gini, max_depth=450, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=200; total time=   0.7s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=6, min_samples_split=1, n_estimators=1400; total time=   1.2s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=6, min_samples_split=1, n_estimators=1400; total time=   1.2s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=6, min_samples_split=1, n_estimators=1400; total time=   1.2s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=2000; total time=   7.4s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=2000; total time=   4.6s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=2000; total time=   4.6s
# [CV] END criterion=entropy, max_depth=560, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   1.5s
# [CV] END criterion=entropy, max_depth=560, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   1.6s
# [CV] END criterion=entropy, max_depth=560, max_features=auto, min_samples_leaf=6, min_samples_split=5, n_estimators=800; total time=   1.8s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=4, min_samples_split=1, n_estimators=1400; total time=   0.7s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=4, min_samples_split=1, n_estimators=1400; total time=   0.7s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=4, min_samples_split=1, n_estimators=1400; total time=   0.6s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   2.1s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   2.2s
# [CV] END criterion=gini, max_depth=890, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   1.9s
# [CV] END criterion=gini, max_depth=340, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=340, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=340, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   0.8s
# [CV] END criterion=entropy, max_depth=340, max_features=auto, min_samples_leaf=8, min_samples_split=9, n_estimators=600; total time=   1.2s
# [CV] END criterion=entropy, max_depth=340, max_features=auto, min_samples_leaf=8, min_samples_split=9, n_estimators=600; total time=   1.4s
# [CV] END criterion=entropy, max_depth=340, max_features=auto, min_samples_leaf=8, min_samples_split=9, n_estimators=600; total time=   1.1s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=1600; total time=   3.9s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=1600; total time=   3.7s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=1600; total time=   4.3s
# [CV] END criterion=entropy, max_depth=450, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=2000; total time=   5.1s
# [CV] END criterion=entropy, max_depth=450, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=2000; total time=   5.5s
# [CV] END criterion=entropy, max_depth=450, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=2000; total time=   4.4s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=1400; total time=   2.9s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=1400; total time=   3.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=1400; total time=   3.0s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=600; total time=   1.1s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=600; total time=   1.1s
# [CV] END criterion=gini, max_depth=120, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=600; total time=   1.0s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=1, n_estimators=1400; total time=   0.6s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=1, n_estimators=1400; total time=   0.7s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=2, min_samples_split=1, n_estimators=1400; total time=   0.7s
# [CV] END criterion=entropy, max_depth=780, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=1000; total time=   2.5s
# [CV] END criterion=entropy, max_depth=780, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=1000; total time=   2.7s
# [CV] END criterion=entropy, max_depth=780, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=1000; total time=   2.8s
# [CV] END criterion=entropy, max_depth=120, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=1800; total time=   4.3s
# [CV] END criterion=entropy, max_depth=120, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=1800; total time=   4.2s
# [CV] END criterion=entropy, max_depth=120, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=1800; total time=   4.0s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=4, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=4, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=4, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=2000; total time=   4.9s
# [CV] END criterion=entropy, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=2000; total time=   5.3s
# [CV] END criterion=entropy, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=2000; total time=   6.4s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=400; total time=   0.8s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=600; total time=   1.3s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=600; total time=   1.2s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=600; total time=   1.2s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=1, n_estimators=1800; total time=   0.7s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=1, n_estimators=1800; total time=   0.8s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=1, n_estimators=1800; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.2s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=2, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=2, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=780, max_features=auto, min_samples_leaf=2, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=450, max_features=sqrt, min_samples_leaf=6, min_samples_split=4, n_estimators=2000; total time=   4.1s
# [CV] END criterion=entropy, max_depth=450, max_features=sqrt, min_samples_leaf=6, min_samples_split=4, n_estimators=2000; total time=   4.3s
# [CV] END criterion=entropy, max_depth=450, max_features=sqrt, min_samples_leaf=6, min_samples_split=4, n_estimators=2000; total time=   4.9s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=1200; total time=   2.6s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=1200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=1200; total time=   2.6s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=600; total time=   1.1s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=600; total time=   1.2s
# [CV] END criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=600; total time=   1.1s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=1600; total time=   3.4s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=1600; total time=   4.1s
# [CV] END criterion=entropy, max_depth=450, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=1600; total time=   3.5s
# [CV] END criterion=entropy, max_depth=120, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=1600; total time=   3.2s
# [CV] END criterion=entropy, max_depth=120, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=1600; total time=   3.9s
# [CV] END criterion=entropy, max_depth=120, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=1600; total time=   3.3s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=2000; total time=   3.8s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=2000; total time=   4.6s
# [CV] END criterion=gini, max_depth=780, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=2000; total time=   5.2s
# [CV] END criterion=gini, max_depth=560, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=1600; total time=   4.3s
# [CV] END criterion=gini, max_depth=560, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=1600; total time=   5.0s
# [CV] END criterion=gini, max_depth=560, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=1600; total time=   5.5s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=1800; total time=   5.8s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=1800; total time=   5.6s
# [CV] END criterion=gini, max_depth=450, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=1800; total time=   5.2s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=1000; total time=   3.3s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=1000; total time=   3.0s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=1000; total time=   2.8s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=800; total time=   2.4s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=800; total time=   2.4s
# [CV] END criterion=gini, max_depth=560, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=800; total time=   2.4s
# [CV] END criterion=entropy, max_depth=120, max_features=log2, min_samples_leaf=8, min_samples_split=9, n_estimators=1600; total time=   4.1s
# [CV] END criterion=entropy, max_depth=120, max_features=log2, min_samples_leaf=8, min_samples_split=9, n_estimators=1600; total time=   3.9s
# [CV] END criterion=entropy, max_depth=120, max_features=log2, min_samples_leaf=8, min_samples_split=9, n_estimators=1600; total time=   3.9s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=4, min_samples_split=1, n_estimators=800; total time=   0.3s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=4, min_samples_split=1, n_estimators=800; total time=   0.5s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=4, min_samples_split=1, n_estimators=800; total time=   0.4s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.3s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.3s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=1, n_estimators=600; total time=   0.4s
# [CV] END criterion=entropy, max_depth=340, max_features=sqrt, min_samples_leaf=8, min_samples_split=7, n_estimators=1400; total time=   6.0s
# [CV] END criterion=entropy, max_depth=340, max_features=sqrt, min_samples_leaf=8, min_samples_split=7, n_estimators=1400; total time=   3.6s
# [CV] END criterion=entropy, max_depth=340, max_features=sqrt, min_samples_leaf=8, min_samples_split=7, n_estimators=1400; total time=   3.5s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=200; total time=   0.6s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=560, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=8, min_samples_split=9, n_estimators=600; total time=   1.5s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=8, min_samples_split=9, n_estimators=600; total time=   1.6s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=8, min_samples_split=9, n_estimators=600; total time=   1.5s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=2000; total time=   5.4s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=2000; total time=   5.5s
# [CV] END criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=6, min_samples_split=9, n_estimators=2000; total time=   5.2s
# [CV] END criterion=gini, max_depth=560, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=1800; total time=   4.7s
# [CV] END criterion=gini, max_depth=560, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=1800; total time=   4.8s
# [CV] END criterion=gini, max_depth=560, max_features=sqrt, min_samples_leaf=4, min_samples_split=3, n_estimators=1800; total time=   5.2s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=2000; total time=   7.3s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=2000; total time=   6.5s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=2000; total time=   5.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=   4.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=   4.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1800; total time=   4.7s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=1000; total time=   2.3s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=1000; total time=   2.6s
# [CV] END criterion=entropy, max_depth=890, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=1000; total time=   2.4s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=6, min_samples_split=4, n_estimators=600; total time=   1.3s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=6, min_samples_split=4, n_estimators=600; total time=   1.3s
# [CV] END criterion=gini, max_depth=230, max_features=auto, min_samples_leaf=6, min_samples_split=4, n_estimators=600; total time=   1.4s
# [CV] END criterion=gini, max_depth=120, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=120, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=120, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=400; total time=   1.1s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1800; total time=   4.4s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1800; total time=   4.5s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1800; total time=   4.2s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=9, n_estimators=1000; total time=   1.9s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=9, n_estimators=1000; total time=   2.0s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=9, n_estimators=1000; total time=   2.1s
# [CV] END criterion=gini, max_depth=1000, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=1000, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=1000, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=1, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=200; total time=   0.3s
# [CV] END criterion=entropy, max_depth=340, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=1800; total time=   3.8s
# [CV] END criterion=entropy, max_depth=340, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=1800; total time=   4.0s
# [CV] END criterion=entropy, max_depth=340, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=1800; total time=   4.6s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=1000; total time=   2.4s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=1000; total time=   2.8s
# [CV] END criterion=entropy, max_depth=1000, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=1000; total time=   2.7s
# [CV] END criterion=entropy, max_depth=120, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=400; total time=   1.0s
# [CV] END criterion=entropy, max_depth=120, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=120, max_features=log2, min_samples_leaf=6, min_samples_split=4, n_estimators=400; total time=   0.7s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=1800; total time=   4.5s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=1800; total time=   4.6s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=1800; total time=   4.1s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=2000; total time=   4.5s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=2000; total time=   4.1s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=2000; total time=   4.8s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=2000; total time=   5.6s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=2000; total time=   5.1s
# [CV] END criterion=entropy, max_depth=670, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=2000; total time=   4.6s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=7, n_estimators=1400; total time=   3.8s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=7, n_estimators=1400; total time=   3.5s
# [CV] END criterion=entropy, max_depth=230, max_features=log2, min_samples_leaf=6, min_samples_split=7, n_estimators=1400; total time=   3.2s
# [CV] END criterion=entropy, max_depth=560, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1200; total time=   2.8s
# [CV] END criterion=entropy, max_depth=560, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1200; total time=   3.1s
# [CV] END criterion=entropy, max_depth=560, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1200; total time=   2.9s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=2000; total time=   5.4s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=2000; total time=   5.3s
# [CV] END criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=2000; total time=   7.3s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=400; total time=   0.7s
# [CV] END criterion=entropy, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1600; total time=   3.9s
# [CV] END criterion=entropy, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1600; total time=   4.5s
# [CV] END criterion=entropy, max_depth=230, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1600; total time=   5.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=1, n_estimators=2000; total time=   0.9s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=1, n_estimators=2000; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=1, n_estimators=2000; total time=   1.1s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1600; total time=   5.1s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1600; total time=   3.9s
# [CV] END criterion=gini, max_depth=1000, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1600; total time=   5.7s
# [CV] END criterion=entropy, max_depth=120, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.7s
# [CV] END criterion=entropy, max_depth=120, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=120, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=6, min_samples_split=7, n_estimators=600; total time=   2.9s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=6, min_samples_split=7, n_estimators=600; total time=   2.9s
# [CV] END criterion=entropy, max_depth=890, max_features=log2, min_samples_leaf=6, min_samples_split=7, n_estimators=600; total time=   1.8s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=340, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=8, min_samples_split=3, n_estimators=1600; total time=   4.0s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=8, min_samples_split=3, n_estimators=1600; total time=   3.6s
# [CV] END criterion=gini, max_depth=670, max_features=sqrt, min_samples_leaf=8, min_samples_split=3, n_estimators=1600; total time=   3.5s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=1600; total time=   4.2s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=1600; total time=   4.6s
# [CV] END criterion=gini, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=1600; total time=   4.1s
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=100,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [10, 120, 230, 340, 450,
#                                                       560, 670, 780, 890,
#                                                       1000],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 6, 8],
#                                         'min_samples_split': [1, 3, 4, 5, 7, 9],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000, 1200, 1400, 1600,
#                                                          1800, 2000]},
#                    random_state=100, verbose=2)

# %%
rand.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 3,
#  'min_samples_leaf': 8,
#  'max_features': 'auto',
#  'max_depth': 670,
#  'criterion': 'gini'}

# %%
rand.best_score_
# Out:
# 0.7556910569105691

# %%
rand.best_estimator_
# Out:
# RandomForestClassifier(max_depth=670, min_samples_leaf=8, min_samples_split=3,
#                        n_estimators=200)

# %%
y_pred = rand.predict(X_test)
print("Accuracy_score:\n",accuracy_score(y_test,y_pred))
print("confusion matrix:\n",confusion_matrix(y_test,y_pred))
print("classification report:\n",classification_report(y_test,y_pred))
# Out:
# Accuracy_score:
#  0.8051948051948052
# confusion matrix:
#  [[97 10]
#  [20 27]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87       107
#            1       0.73      0.57      0.64        47
#
#     accuracy                           0.81       154
#    macro avg       0.78      0.74      0.75       154
# weighted avg       0.80      0.81      0.80       154

# %% [markdown]
# ### Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'criterion': [rand.best_params_['criterion']],
    'max_depth': [rand.best_params_['max_depth']],
    'max_features': [rand.best_params_['max_features']],
    'min_samples_leaf': [rand.best_params_['min_samples_leaf'], 
                         rand.best_params_['min_samples_leaf']+2, 
                         rand.best_params_['min_samples_leaf'] + 4],
    'min_samples_split': [rand.best_params_['min_samples_split'] - 2,
                          rand.best_params_['min_samples_split'] - 1,
                          rand.best_params_['min_samples_split'], 
                          rand.best_params_['min_samples_split'] +1,
                          rand.best_params_['min_samples_split'] + 2],
    'n_estimators': [rand.best_params_['n_estimators'] - 200, rand.best_params_['n_estimators'] - 100, 
                     rand.best_params_['n_estimators'], 
                     rand.best_params_['n_estimators'] + 100, rand.best_params_['n_estimators'] + 200]
}

print(param_grid)
# Out:
# {'criterion': ['gini'], 'max_depth': [670], 'max_features': ['auto'], 'min_samples_leaf': [8, 10, 12], 'min_samples_split': [1, 2, 3, 4, 5], 'n_estimators': [0, 100, 200, 300, 400]}

# %%
rf = RandomForestClassifier()
grid = GridSearchCV(rf,param_grid,cv=10,verbose=2)
grid.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 75 candidates, totalling 750 fits
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=300; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=400; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=400; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=400; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=400; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=400; total time=   1.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=100; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=400; total time=   1.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=3, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=300; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=200; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=200; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=300; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=400; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=1, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=400; total time=   0.9s
# ...
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=3, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=3, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=3, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=3, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=3, n_estimators=400; total time=   1.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=3, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=3, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=300; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=300; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=300; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=400; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=400; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=400; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=400; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=4, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=0; total time=   0.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=300; total time=   0.7s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=300; total time=   0.6s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=400; total time=   1.1s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=400; total time=   1.0s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=400; total time=   1.3s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=400; total time=   1.2s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=400; total time=   1.4s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=400; total time=   0.9s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=400; total time=   0.8s
# [CV] END criterion=gini, max_depth=670, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=400; total time=   0.8s
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini'], 'max_depth': [670],
#                          'max_features': ['auto'],
#                          'min_samples_leaf': [8, 10, 12],
#                          'min_samples_split': [1, 2, 3, 4, 5],
#                          'n_estimators': [0, 100, 200, 300, 400]},
#              verbose=2)

# %%
grid.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 670,
#  'max_features': 'auto',
#  'min_samples_leaf': 12,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
grid.best_score_
# Out:
# 0.7653622421998942

# %%
grid.best_estimator_
# Out:
# RandomForestClassifier(max_depth=670, min_samples_leaf=12)

# %%
y_pred = grid.predict(X_test)
print("Accuracy_score:\n",accuracy_score(y_test,y_pred))
print("confusion matrix:\n",confusion_matrix(y_test,y_pred))
print("classification report:\n",classification_report(y_test,y_pred))
# Out:
# Accuracy_score:
#  0.8311688311688312
# confusion matrix:
#  [[98  9]
#  [17 30]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88       107
#            1       0.77      0.64      0.70        47
#
#     accuracy                           0.83       154
#    macro avg       0.81      0.78      0.79       154
# weighted avg       0.83      0.83      0.83       154

# %% [markdown]
# ### Automated Hyperparameter Tuning
#
# Automated Hyperparameter Tuning can be done by using techniques such as
#
# - Bayesian Optimization
# - Gradient Descent
# - Evolutionary Algorithms
#
# ### Bayesian Optimization
#
# Bayesian optimization uses probability to find the minimum of a function. The final aim is to find the input value to a function which can gives us the lowest possible output value.It usually performs better than random,grid and manual search providing better performance in the testing phase and reduced optimization time. In Hyperopt, Bayesian Optimization can be implemented giving 3 three main parameters to the function fmin.
#
# - Objective Function = defines the loss function to minimize.
# - Domain Space = defines the range of input values to test (in Bayesian Optimization this space creates a probability distribution for each of the used Hyperparameters).
# - Optimization Algorithm = defines the search algorithm to use to select the best input values to use in each new iteration.

# %%
! pip install hyperopt
# Out:
# Collecting hyperopt
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: six in c:\users\saura\anaconda3\lib\site-packages (from hyperopt) (1.15.0)
# Collecting py4j
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
# Requirement already satisfied: future in c:\users\saura\anaconda3\lib\site-packages (from hyperopt) (0.18.2)
# Requirement already satisfied: cloudpickle in c:\users\saura\anaconda3\lib\site-packages (from hyperopt) (1.6.0)
# Requirement already satisfied: tqdm in c:\users\saura\anaconda3\lib\site-packages (from hyperopt) (4.50.2)
# Requirement already satisfied: networkx>=2.2 in c:\users\saura\anaconda3\lib\site-packages (from hyperopt) (2.5)
# Requirement already satisfied: numpy in c:\users\saura\anaconda3\lib\site-packages (from hyperopt) (1.23.0)
# Requirement already satisfied: scipy in c:\users\saura\anaconda3\lib\site-packages (from hyperopt) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\saura\anaconda3\lib\site-packages (from networkx>=2.2->hyperopt) (4.4.2)
# Installing collected packages: py4j, hyperopt
# Successfully installed hyperopt-0.2.7 py4j-0.10.9.7

# %%
from hyperopt import hp,fmin,tpe,STATUS_OK,Trials

# %%
space = {'criterion': hp.choice('criterion', ['entropy', 'gini']),
        'max_depth': hp.quniform('max_depth', 10, 1200, 10),
        'max_features': hp.choice('max_features', ['auto', 'sqrt','log2', None]),
        'min_samples_leaf': hp.uniform('min_samples_leaf', 0, 0.5),
        'min_samples_split' : hp.uniform ('min_samples_split', 0, 1),
        'n_estimators' : hp.choice('n_estimators', [10, 50, 300, 750, 1200,1300,1500])
    }

# %%
space
# Out:
# {'criterion': <hyperopt.pyll.base.Apply at 0x262cf9d4340>,
#  'max_depth': <hyperopt.pyll.base.Apply at 0x262cf9d44f0>,
#  'max_features': <hyperopt.pyll.base.Apply at 0x262cf9d4610>,
#  'min_samples_leaf': <hyperopt.pyll.base.Apply at 0x262cf9d47f0>,
#  'min_samples_split': <hyperopt.pyll.base.Apply at 0x262cf9d4910>,
#  'n_estimators': <hyperopt.pyll.base.Apply at 0x262cf9d4a00>}

# %%
from sklearn.model_selection import cross_val_score

# %%
def objective(space):
    model = RandomForestClassifier(criterion = space['criterion'], max_depth = space['max_depth'],
                                 max_features = space['max_features'],
                                 min_samples_leaf = space['min_samples_leaf'],
                                 min_samples_split = space['min_samples_split'],
                                 n_estimators = space['n_estimators'], 
                                 )
    
    accuracy = cross_val_score(model, X_train, y_train, cv = 5).mean()

    # We aim to maximize accuracy, therefore we return it as a negative value
    return {'loss': -accuracy, 'status': STATUS_OK }

# %%
trials = Trials()
best = fmin(fn= objective,
            space= space,
            algo= tpe.suggest,
            max_evals = 80,
            trials= trials)
best
# Out:
# 100%|███████████████████████████████████████████████| 80/80 [10:07<00:00,  7.60s/trial, best loss: -0.7638544582167134]
# {'criterion': 1,
#  'max_depth': 1100.0,
#  'max_features': 0,
#  'min_samples_leaf': 0.057595545016498564,
#  'min_samples_split': 0.048516623331539804,
#  'n_estimators': 1}

# %%
best["criterion"]

# %%
crit = {0: 'entropy', 1: 'gini'}
feat = {0: 'auto', 1: 'sqrt', 2: 'log2', 3: None}
est = {0: 10, 1: 50, 2: 300, 3: 750, 4: 1200,5:1300,6:1500}


print(crit[best['criterion']])
print(feat[best['max_features']])
print(est[best['n_estimators']])
# Out:
# gini
# auto
# 50

# %%
trainedforest = RandomForestClassifier(criterion = crit[best['criterion']], max_depth = best['max_depth'], 
                                       max_features = feat[best['max_features']], 
                                       min_samples_leaf = best['min_samples_leaf'], 
                                       min_samples_split = best['min_samples_split'], 
                                       n_estimators = est[best['n_estimators']]).fit(X_train,y_train)
predictionforest = trainedforest.predict(X_test)
print(confusion_matrix(y_test,predictionforest))
print(accuracy_score(y_test,predictionforest))
print(classification_report(y_test,predictionforest))
acc5 = accuracy_score(y_test,predictionforest)
# Out:
# [[99  8]
#  [24 23]]
# 0.7922077922077922
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86       107
#            1       0.74      0.49      0.59        47
#
#     accuracy                           0.79       154
#    macro avg       0.77      0.71      0.73       154
# weighted avg       0.79      0.79      0.78       154

# %% [markdown]
# ### Genetic Algorithms
#
# Genetic Algorithms tries to apply natural selection mechanisms to Machine Learning contexts.
#
# Let's imagine we create a population of N Machine Learning models with some predifined Hyperparameters. We can then calculate the accuracy of each model and decide to keep just half of the models (the ones that performs best). We can now generate some offsprings having similar Hyperparameters to the ones of the best models so that go get again a population of N models. At this point we can again calculate the accuracy of each model and repeat the cycle for a defined number of generations. In this way, just the best models will survive at the end of the process.

# %%
params = {
 # Number of trees in random forest
"n_estimators": [int(x) for x in np.linspace(200,2000,10)],
 # Number of features to consider at every split
"max_features" : ["auto","sqrt","log2"],
 # Maximum number of levels in tree
"max_depth" : [int(x) for x in np.linspace(10,1000,10)],
 # Minimum number of samples required to split a node
"min_samples_split": [1,3,4,5,7,9],
 # Minimum number of samples required at each leaf node
"min_samples_leaf" : [1,2,4,6,8],
"criterion":["entropy","gini"]
    }

# %%
params
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000],
#  'max_features': ['auto', 'sqrt', 'log2'],
#  'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000],
#  'min_samples_split': [1, 3, 4, 5, 7, 9],
#  'min_samples_leaf': [1, 2, 4, 6, 8],
#  'criterion': ['entropy', 'gini']}

# %%
! pip install tpot
# Out:
# Collecting tpot
#   Downloading TPOT-0.11.7-py3-none-any.whl (87 kB)
# Collecting stopit>=1.1.1
#   Downloading stopit-1.1.2.tar.gz (18 kB)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\saura\anaconda3\lib\site-packages (from tpot) (1.23.0)
# Requirement already satisfied: xgboost>=1.1.0 in c:\users\saura\anaconda3\lib\site-packages (from tpot) (1.5.2)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\saura\anaconda3\lib\site-packages (from tpot) (4.50.2)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\saura\anaconda3\lib\site-packages (from tpot) (1.1.3)
# Collecting deap>=1.2
#   Downloading deap-1.3.3-cp38-cp38-win_amd64.whl (109 kB)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\saura\anaconda3\lib\site-packages (from tpot) (1.0.1)
# Collecting update-checker>=0.16
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: scipy>=1.3.1 in c:\users\saura\anaconda3\lib\site-packages (from tpot) (1.5.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\saura\anaconda3\lib\site-packages (from tpot) (1.0.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\saura\anaconda3\lib\site-packages (from pandas>=0.24.2->tpot) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\saura\anaconda3\lib\site-packages (from pandas>=0.24.2->tpot) (2.8.1)
# Requirement already satisfied: requests>=2.3.0 in c:\users\saura\anaconda3\lib\site-packages (from update-checker>=0.16->tpot) (2.24.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\saura\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->tpot) (2.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\saura\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->tpot) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saura\anaconda3\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\saura\anaconda3\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\saura\anaconda3\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\saura\anaconda3\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.25.11)
# Building wheels for collected packages: stopit
#   Building wheel for stopit (setup.py): started
#   Building wheel for stopit (setup.py): finished with status 'done'
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11959 sha256=438d30e909428e3e49cc8b81c2781f2f670c8ae0f7aa6c234f6a3fa5f596283c
#   Stored in directory: c:\users\saura\appdata\local\pip\cache\wheels\a8\bb\8f\6b9328d23c2dcedbfeb8498b9f650d55d463089e3b8fc0bfb2
# Successfully built stopit
# Installing collected packages: stopit, deap, update-checker, tpot
# Successfully installed deap-1.3.3 stopit-1.1.2 tpot-0.11.7 update-checker-0.18.0

# %%
from tpot import TPOTClassifier


tpot_classifier = TPOTClassifier(generations= 5, population_size= 24, offspring_size= 12,
                                 verbosity= 2, early_stop= 12,
                                 config_dict={'sklearn.ensemble.RandomForestClassifier': params}, 
                                 cv = 4, scoring = 'accuracy')
tpot_classifier.fit(X_train,y_train)
# Out:
# HBox(children=(HTML(value='Optimization Progress'), FloatProgress(value=0.0, max=84.0), HTML(value='')))
# Generation 1 - Current best internal CV score: 0.7670613700025465
#
# Generation 2 - Current best internal CV score: 0.7670613700025465
#
# Generation 3 - Current best internal CV score: 0.7670613700025465
#
# Generation 4 - Current best internal CV score: 0.7670613700025465
#
# Generation 5 - Current best internal CV score: 0.7670613700025465
#
# Best pipeline: RandomForestClassifier(RandomForestClassifier(input_matrix, criterion=entropy, max_depth=560, max_features=sqrt, min_samples_leaf=8, min_samples_split=7, n_estimators=200), criterion=entropy, max_depth=670, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=1600)
# TPOTClassifier(config_dict={'sklearn.ensemble.RandomForestClassifier': {'criterion': ['entropy',
#                                                                                       'gini'],
#                                                                         'max_depth': [10,
#                                                                                       120,
#                                                                                       230,
#                                                                                       340,
#                                                                                       450,
#                                                                                       560,
#                                                                                       670,
#                                                                                       780,
#                                                                                       890,
#                                                                                       1000],
#                                                                         'max_features': ['auto',
#                                                                                          'sqrt',
#                                                                                          'log2'],
#                                                                         'min_samples_leaf': [1,
#                                                                                              2,
#                                                                                              4,
#                                                                                              6,
#                                                                                              8],
#                                                                         'min_samples_split': [1,
#                                                                                               3,
#                                                                                               4,
#                                                                                               5,
#                                                                                               7,
#                                                                                               9],
#                                                                         'n_estimators': [200,
#                                                                                          400,
#                                                                                          600,
#                                                                                          800,
#                                                                                          1000,
#                                                                                          1200,
#                                                                                          1400,
#                                                                                          1600,
#                                                                                          1800,
#                                                                                          2000]}},
#                cv=4, early_stop=12, generations=5, offspring_size=12,
#                population_size=24, scoring='accuracy', verbosity=2)

# %%
accuracy = tpot_classifier.score(X_test, y_test)
print(accuracy)
# Out:
# 0.8376623376623377

# %% [markdown]
# ### Optimize hyperparameters of the model using Optuna
#
# The hyperparameters of the above algorithm are n_estimators and max_depth for which we can try different values to see if the model accuracy can be improved. The objective function is modified to accept a trial object. This trial has several methods for sampling hyperparameters. We create a study to run the hyperparameter optimization and finally read the best hyperparameters.

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.1.0-py3-none-any.whl (365 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\saura\anaconda3\lib\site-packages (from optuna) (20.4)
# Requirement already satisfied: numpy in c:\users\saura\anaconda3\lib\site-packages (from optuna) (1.23.0)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: tqdm in c:\users\saura\anaconda3\lib\site-packages (from optuna) (4.50.2)
# Requirement already satisfied: PyYAML in c:\users\saura\anaconda3\lib\site-packages (from optuna) (5.3.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\saura\anaconda3\lib\site-packages (from optuna) (1.3.20)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.10.2-py3-none-any.whl (212 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\saura\anaconda3\lib\site-packages (from packaging>=20.0->optuna) (2.4.7)
# Requirement already satisfied: six in c:\users\saura\anaconda3\lib\site-packages (from packaging>=20.0->optuna) (1.15.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\saura\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.4)
# Requirement already satisfied: importlib-metadata; python_version < "3.9" in c:\users\saura\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.12.0)
# Collecting importlib-resources; python_version < "3.9"
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
# Collecting typing-extensions>=4
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\saura\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.9"->alembic>=1.5.0->optuna) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\saura\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.0.1)
# Installing collected packages: cmaes, colorlog, importlib-resources, Mako, typing-extensions, alembic, optuna
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
# Successfully installed Mako-1.2.4 alembic-1.10.2 cmaes-0.9.1 colorlog-6.7.0 importlib-resources-5.12.0 optuna-3.1.0 typing-extensions-4.5.0

# %%
import optuna
import sklearn.svm
def objective(trial):

    classifier = trial.suggest_categorical('classifier', ['RandomForest', 'SVC'])
    
    if classifier == 'RandomForest':
        n_estimators = trial.suggest_int('n_estimators', 200, 2000,10)
        max_depth = int(trial.suggest_float('max_depth', 10, 100, log=True))

        clf = sklearn.ensemble.RandomForestClassifier(
            n_estimators=n_estimators, max_depth=max_depth)
    else:
        c = trial.suggest_float('svc_c', 1e-10, 1e10, log=True)
        
        clf = sklearn.svm.SVC(C=c, gamma='auto')

    return sklearn.model_selection.cross_val_score(
        clf,X_train,y_train, n_jobs=-1, cv=3).mean()

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

trial = study.best_trial

print('Accuracy: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))
# Out:
# [I 2023-03-24 18:30:28,578] A new study created in memory with name: no-name-ce306800-fdfa-46e6-a404-5a9423a8fbfe
# [I 2023-03-24 18:30:37,490] Trial 0 finished with value: 0.7475450342738722 and parameters: {'classifier': 'RandomForest', 'n_estimators': 810, 'max_depth': 69.66562030071431}. Best is trial 0 with value: 0.7475450342738722.
# [I 2023-03-24 18:30:44,884] Trial 1 finished with value: 0.7491790212019768 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1100, 'max_depth': 93.92960304318582}. Best is trial 1 with value: 0.7491790212019768.
# [I 2023-03-24 18:30:49,823] Trial 2 finished with value: 0.7556830862426271 and parameters: {'classifier': 'RandomForest', 'n_estimators': 570, 'max_depth': 21.17646430467971}. Best is trial 2 with value: 0.7556830862426271.
# [I 2023-03-24 18:30:53,870] Trial 3 finished with value: 0.7475370636059302 and parameters: {'classifier': 'RandomForest', 'n_estimators': 840, 'max_depth': 25.555460021946132}. Best is trial 2 with value: 0.7556830862426271.
# [I 2023-03-24 18:30:54,154] Trial 4 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 1.6841107166492192e-10}. Best is trial 2 with value: 0.7556830862426271.
# [I 2023-03-24 18:30:54,244] Trial 5 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 0.3067641655838128}. Best is trial 2 with value: 0.7556830862426271.
# [I 2023-03-24 18:30:54,322] Trial 6 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 4.376259360541872e-06}. Best is trial 2 with value: 0.7556830862426271.
# [I 2023-03-24 18:31:00,876] Trial 7 finished with value: 0.7524310537223019 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1800, 'max_depth': 15.688929929824486}. Best is trial 2 with value: 0.7556830862426271.
# [I 2023-03-24 18:31:02,553] Trial 8 finished with value: 0.7540490993145226 and parameters: {'classifier': 'RandomForest', 'n_estimators': 430, 'max_depth': 62.46872876600841}. Best is trial 2 with value: 0.7556830862426271.
# [I 2023-03-24 18:31:02,666] Trial 9 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 0.025286419643363697}. Best is trial 2 with value: 0.7556830862426271.
# [I 2023-03-24 18:31:04,075] Trial 10 finished with value: 0.7524390243902439 and parameters: {'classifier': 'RandomForest', 'n_estimators': 350, 'max_depth': 10.35009661763835}. Best is trial 2 with value: 0.7556830862426271.
# [I 2023-03-24 18:31:04,842] Trial 11 finished with value: 0.7507890961262554 and parameters: {'classifier': 'RandomForest', 'n_estimators': 210, 'max_depth': 42.849251667059534}. Best is trial 2 with value: 0.7556830862426271.
# [I 2023-03-24 18:31:06,591] Trial 12 finished with value: 0.7475370636059302 and parameters: {'classifier': 'RandomForest', 'n_estimators': 520, 'max_depth': 34.77853000295409}. Best is trial 2 with value: 0.7556830862426271.
# [I 2023-03-24 18:31:08,980] Trial 13 finished with value: 0.7491790212019768 and parameters: {'classifier': 'RandomForest', 'n_estimators': 680, 'max_depth': 54.66978792749062}. Best is trial 2 with value: 0.7556830862426271.
# [I 2023-03-24 18:31:15,096] Trial 14 finished with value: 0.7508130081300813 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1450, 'max_depth': 24.874804503974254}. Best is trial 2 with value: 0.7556830862426271.
# [I 2023-03-24 18:31:19,627] Trial 15 finished with value: 0.7556910569105691 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1140, 'max_depth': 47.360486299705876}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:31:24,189] Trial 16 finished with value: 0.7475450342738722 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1240, 'max_depth': 29.028063006039744}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:31:28,258] Trial 17 finished with value: 0.7475609756097561 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1120, 'max_depth': 18.434577751314805}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:31:28,392] Trial 18 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 5634138486.944507}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:31:33,487] Trial 19 finished with value: 0.7491710505340348 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1470, 'max_depth': 38.61322567081924}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:31:36,847] Trial 20 finished with value: 0.7508050374621393 and parameters: {'classifier': 'RandomForest', 'n_estimators': 940, 'max_depth': 47.03730813630321}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:31:38,663] Trial 21 finished with value: 0.7491869918699187 and parameters: {'classifier': 'RandomForest', 'n_estimators': 520, 'max_depth': 61.92711203676726}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:31:40,539] Trial 22 finished with value: 0.744293001753547 and parameters: {'classifier': 'RandomForest', 'n_estimators': 480, 'max_depth': 72.277375518872}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:31:43,017] Trial 23 finished with value: 0.7443089430894309 and parameters: {'classifier': 'RandomForest', 'n_estimators': 650, 'max_depth': 49.87350101397896}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:31:44,317] Trial 24 finished with value: 0.7507890961262554 and parameters: {'classifier': 'RandomForest', 'n_estimators': 280, 'max_depth': 36.85400693285794}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:31:49,682] Trial 25 finished with value: 0.7556910569105691 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1380, 'max_depth': 91.53731600390928}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:31:49,790] Trial 26 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 49375209.57845146}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:31:54,785] Trial 27 finished with value: 0.7524310537223019 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1390, 'max_depth': 99.63576864631563}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:32:00,694] Trial 28 finished with value: 0.7540650406504065 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1720, 'max_depth': 77.28647919961003}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:32:07,651] Trial 29 finished with value: 0.7508050374621393 and parameters: {'classifier': 'RandomForest', 'n_estimators': 2000, 'max_depth': 84.69308849003902}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:32:11,955] Trial 30 finished with value: 0.7475530049418141 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1220, 'max_depth': 59.53900665767605}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:32:17,972] Trial 31 finished with value: 0.7540490993145226 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1690, 'max_depth': 79.6550154432164}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:32:24,854] Trial 32 finished with value: 0.7540650406504065 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1720, 'max_depth': 82.26847274321374}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:32:30,516] Trial 33 finished with value: 0.7508050374621393 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1590, 'max_depth': 71.9903926295962}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:32:35,128] Trial 34 finished with value: 0.7459269886816515 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1310, 'max_depth': 99.01529613220738}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:32:42,417] Trial 35 finished with value: 0.7540650406504065 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1920, 'max_depth': 50.511503302987784}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:32:42,551] Trial 36 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 116205.19094245274}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:32:46,909] Trial 37 finished with value: 0.7491790212019768 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1080, 'max_depth': 64.68770810696059}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:32:47,066] Trial 38 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 1045.9902926488496}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:32:52,395] Trial 39 finished with value: 0.7475450342738722 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1570, 'max_depth': 76.99403579740436}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:32:55,390] Trial 40 finished with value: 0.744285031085605 and parameters: {'classifier': 'RandomForest', 'n_estimators': 870, 'max_depth': 87.27159034700294}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:33:01,432] Trial 41 finished with value: 0.7540650406504065 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1770, 'max_depth': 84.06309738296605}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:33:04,923] Trial 42 finished with value: 0.7507970667941973 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1000, 'max_depth': 72.14788214615217}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:33:11,795] Trial 43 finished with value: 0.7540650406504065 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1640, 'max_depth': 86.47756218770036}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:33:19,112] Trial 44 finished with value: 0.75242308305436 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1830, 'max_depth': 68.14851987537153}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:33:24,363] Trial 45 finished with value: 0.7508050374621393 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1340, 'max_depth': 57.58238001482557}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:33:24,495] Trial 46 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 83.731042218776}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:33:32,532] Trial 47 finished with value: 0.7508050374621393 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1720, 'max_depth': 91.43780513016176}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:33:38,821] Trial 48 finished with value: 0.7508050374621393 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1530, 'max_depth': 76.45191499733407}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:33:42,910] Trial 49 finished with value: 0.7410250278973378 and parameters: {'classifier': 'RandomForest', 'n_estimators': 740, 'max_depth': 68.13802813380799}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:33:50,385] Trial 50 finished with value: 0.7491790212019768 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1860, 'max_depth': 55.661703953532935}. Best is trial 15 with value: 0.7556910569105691.
# [I 2023-03-24 18:34:00,833] Trial 51 finished with value: 0.755699027578511 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1980, 'max_depth': 51.360107817914006}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:34:10,736] Trial 52 finished with value: 0.7475370636059302 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1180, 'max_depth': 41.63165860721133}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:34:21,891] Trial 53 finished with value: 0.7540650406504065 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1950, 'max_depth': 62.875277496990606}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:34:33,966] Trial 54 finished with value: 0.7508050374621393 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1730, 'max_depth': 92.43247524016935}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:34:41,410] Trial 55 finished with value: 0.7475530049418141 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1460, 'max_depth': 44.638748347658584}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:34:49,097] Trial 56 finished with value: 0.7540650406504065 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1900, 'max_depth': 32.14616507209987}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:34:49,177] Trial 57 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 4.798550536788311e-05}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:34:53,130] Trial 58 finished with value: 0.7508050374621393 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1010, 'max_depth': 52.76537817717303}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:34:58,094] Trial 59 finished with value: 0.7524390243902439 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1310, 'max_depth': 46.64844147964444}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:35:06,270] Trial 60 finished with value: 0.7491790212019768 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1640, 'max_depth': 79.89968109413861}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:35:14,862] Trial 61 finished with value: 0.7459190180137095 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1920, 'max_depth': 53.120852449589954}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:35:23,482] Trial 62 finished with value: 0.744285031085605 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1980, 'max_depth': 39.850831902302424}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:35:30,817] Trial 63 finished with value: 0.7540650406504065 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1800, 'max_depth': 47.317205657925484}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:35:37,937] Trial 64 finished with value: 0.75242308305436 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1890, 'max_depth': 50.18108088313499}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:35:44,544] Trial 65 finished with value: 0.7459269886816515 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1790, 'max_depth': 61.517114009338954}. Best is trial 51 with value: 0.755699027578511.
# [I 2023-03-24 18:35:46,906] Trial 66 finished with value: 0.7573250438386737 and parameters: {'classifier': 'RandomForest', 'n_estimators': 620, 'max_depth': 43.5998033941483}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:35:49,347] Trial 67 finished with value: 0.7459110473457676 and parameters: {'classifier': 'RandomForest', 'n_estimators': 640, 'max_depth': 41.70905481964612}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:35:49,451] Trial 68 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 783117.4234337744}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:35:50,825] Trial 69 finished with value: 0.7507970667941973 and parameters: {'classifier': 'RandomForest', 'n_estimators': 370, 'max_depth': 37.426749474295285}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:35:53,255] Trial 70 finished with value: 0.7459269886816515 and parameters: {'classifier': 'RandomForest', 'n_estimators': 540, 'max_depth': 55.61555539999491}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:35:56,306] Trial 71 finished with value: 0.7524469950581859 and parameters: {'classifier': 'RandomForest', 'n_estimators': 850, 'max_depth': 50.60068795937696}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:35:59,357] Trial 72 finished with value: 0.7491790212019768 and parameters: {'classifier': 'RandomForest', 'n_estimators': 780, 'max_depth': 44.87849204807528}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:36:03,682] Trial 73 finished with value: 0.7524310537223019 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1160, 'max_depth': 64.83194082173222}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:36:08,772] Trial 74 finished with value: 0.7508050374621393 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1380, 'max_depth': 33.70700440733714}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:36:10,927] Trial 75 finished with value: 0.7475530049418141 and parameters: {'classifier': 'RandomForest', 'n_estimators': 590, 'max_depth': 29.846519082778276}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:36:12,868] Trial 76 finished with value: 0.744300972421489 and parameters: {'classifier': 'RandomForest', 'n_estimators': 420, 'max_depth': 58.58755156352865}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:36:20,286] Trial 77 finished with value: 0.7507970667941973 and parameters: {'classifier': 'RandomForest', 'n_estimators': 2000, 'max_depth': 24.257711253016094}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:36:28,739] Trial 78 finished with value: 0.7475530049418141 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1510, 'max_depth': 95.75004807337251}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:36:28,911] Trial 79 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 5.770121091280967e-10}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:36:30,154] Trial 80 finished with value: 0.7410250278973378 and parameters: {'classifier': 'RandomForest', 'n_estimators': 230, 'max_depth': 77.84969531885348}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:36:36,810] Trial 81 finished with value: 0.7508130081300813 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1750, 'max_depth': 84.60013158652045}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:36:45,088] Trial 82 finished with value: 0.7491710505340348 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1680, 'max_depth': 73.25666143324167}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:36:52,828] Trial 83 finished with value: 0.7508050374621393 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1840, 'max_depth': 84.5228689443046}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:36:58,233] Trial 84 finished with value: 0.7475609756097561 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1780, 'max_depth': 67.00527544303173}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:02,612] Trial 85 finished with value: 0.7508050374621393 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1610, 'max_depth': 99.95008149177964}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:05,158] Trial 86 finished with value: 0.7507970667941973 and parameters: {'classifier': 'RandomForest', 'n_estimators': 930, 'max_depth': 92.90070388161901}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:08,260] Trial 87 finished with value: 0.7524310537223019 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1090, 'max_depth': 59.21213170319349}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:10,323] Trial 88 finished with value: 0.7491949625378607 and parameters: {'classifier': 'RandomForest', 'n_estimators': 710, 'max_depth': 70.50952229534646}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:13,996] Trial 89 finished with value: 0.7459269886816515 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1250, 'max_depth': 75.67547221955408}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:19,541] Trial 90 finished with value: 0.7508050374621393 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1860, 'max_depth': 86.30433166881129}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:23,916] Trial 91 finished with value: 0.7508130081300813 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1650, 'max_depth': 81.38792437787606}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:29,065] Trial 92 finished with value: 0.7475450342738722 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1940, 'max_depth': 82.32319747286027}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:33,079] Trial 93 finished with value: 0.7540650406504065 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1540, 'max_depth': 88.48334297565799}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:37,603] Trial 94 finished with value: 0.7491710505340348 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1750, 'max_depth': 91.05147275947282}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:41,230] Trial 95 finished with value: 0.7556910569105691 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1420, 'max_depth': 73.99582612450673}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:41,301] Trial 96 finished with value: 0.640068547744301 and parameters: {'classifier': 'SVC', 'svc_c': 4155233309.6900277}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:44,924] Trial 97 finished with value: 0.7475450342738722 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1400, 'max_depth': 69.2292350126203}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:47,752] Trial 98 finished with value: 0.7475530049418141 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1050, 'max_depth': 75.18149952476445}. Best is trial 66 with value: 0.7573250438386737.
# [I 2023-03-24 18:37:52,167] Trial 99 finished with value: 0.7508130081300813 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1700, 'max_depth': 64.47463008424792}. Best is trial 66 with value: 0.7573250438386737.
# Accuracy: 0.7573250438386737
# Best hyperparameters: {'classifier': 'RandomForest', 'n_estimators': 620, 'max_depth': 43.5998033941483}

# %%
trial
# Out:
# FrozenTrial(number=66, state=TrialState.COMPLETE, values=[0.7573250438386737], datetime_start=datetime.datetime(2023, 3, 24, 18, 35, 44, 547324), datetime_complete=datetime.datetime(2023, 3, 24, 18, 35, 46, 904922), params={'classifier': 'RandomForest', 'n_estimators': 620, 'max_depth': 43.5998033941483}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'classifier': CategoricalDistribution(choices=('RandomForest', 'SVC')), 'n_estimators': IntDistribution(high=2000, log=False, low=200, step=10), 'max_depth': FloatDistribution(high=100.0, log=True, low=10.0, step=None)}, trial_id=66, value=None)

# %%
study.best_params
# Out:
# {'classifier': 'RandomForest',
#  'n_estimators': 620,
#  'max_depth': 43.5998033941483}

# %%
rf=RandomForestClassifier(n_estimators=330,max_depth=30)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=30, n_estimators=330)

# %%
y_pred=rf.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[95 12]
#  [17 30]]
# 0.8116883116883117
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87       107
#            1       0.71      0.64      0.67        47
#
#     accuracy                           0.81       154
#    macro avg       0.78      0.76      0.77       154
# weighted avg       0.81      0.81      0.81       154
